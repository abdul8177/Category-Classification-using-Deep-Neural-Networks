# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline
import json

# %%
with open("data_json_small.json") as d:
    file = json.load(d)

# %%
data = []
for conversation_dataset in file['conversation_dataset']:
    for conversation in conversation_dataset['conversation']:
        for turns in conversation['turns']:
            data.append([turns['utterance'], turns['category'][0]])

# %%
df = pd.DataFrame(data, columns= ['utterance', 'category'])

# %%
plt.figure(figsize=[12,10])
sns.countplot(df.category)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
plt.show()

# %%
X = df.utterance
Y = df.category
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
Y
# Out:
# array([[0],
#        [3],
#        [1],
#        ...,
#        [6],
#        [2],
#        [6]])

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %%
X_train
# Out:
# 163     Happy that we could help.  I've also logged ca...
# 882                                         It's   247252
# 79                              Okay my number is  237996
# 503                                           Wow, thanks
# 674                                  I'll confirm  179833
# 838                                          It is 325501
# 80                     I'll repeat, please confirm 237996
# 117     Okay. Your name matches with records. In your ...
# 469     Thanks for confirming. Balance in your account...
# 125                                                  good
# 321                                          It is 254828
# 40          Thanks for confirming. Your balance is 302771
# 527                                            No, thanks
# 27      Okay. For mandatory verification purpose, may ...
# 1075                                          Super. Cool
# 183         Thanks for confirming. Your balance is 260962
# 785                                               correct
# 858     Good morning . I got a fund transfer today mor...
# 725                                          Nothing, bye
# 625     Glad we were of help to you. I have also regis...
# 52                                            Wow, thanks
# 214     Great. Could you please let me know your name ...
# 765                                  This is  Gopal Singh
# 477                                             it's okay
# 607                           My account number is  54949
# 912                                              Nah, bye
# 872                          Just to confirm, it's 239521
# 374     Hello . My friend sent some money today .  I t...
# 289                                   I'll confirm  12533
# 17                                     This is  Kiran Rao
#                               ...
# 994                                                  good
# 1059                   I'll repeat, please confirm 209598
# 126     That's good. Please state your name as in the ...
# 142                                               Nothing
# 677                                     It is  John Smith
# 559     Happy that we could help.  I've raised ticket ...
# 495     Good afternoon . I wanted to send money to my ...
# 221     I regret the inconvenience caused. Will surely...
# 823     Good that we resolved your issue.  I have also...
# 830     Okay. For mandatory verification purpose, may ...
# 537     Good that we resolved your issue.  I've also l...
# 426                                           Wow, thanks
# 726     Hi . I wanted to withdraw money from my accoun...
# 889     Glad we could help you.  I've also logged call...
# 253     Good morning . I got a fund transfer today mor...
# 483                                               No, bye
# 968     Good morning . I wanted to do a fund transfer ...
# 246                                                  okay
# 741                                               perfect
# 355                          Just to confirm, it's 168108
# 835                                              Nah, bye
# 985                                         I'm Ram Smith
# 196     Good that we resolved your issue.  I have also...
# 113                                Your number is  327298
# 647     Glad we could help you.  I've raised ticket on...
# 749     Sorry to know about your problems, we can defi...
# 786     Okay. For mandatory verification purpose, may ...
# 268                                             it's okay
# 286     Hello . Yesterday I did few transactions . So ...
# 1080                     This is my account number 331181
# Name: utterance, Length: 935, dtype: object

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len)

# %%
sequences
# Out:
# [[97,
#   12,
#   34,
#   22,
#   16,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   238,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [49, 165],
#  [43, 10, 7, 4, 166],
#  [143, 30],
#  [73, 59, 167],
#  [25, 4, 168],
#  [73, 81, 11, 59, 166],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 239],
#  [30, 6, 70, 9, 13, 3, 5, 4, 240],
#  [26],
#  [25, 4, 169],
#  [30, 6, 70, 3, 9, 4, 241],
#  [45, 30],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [112, 74],
#  [30, 6, 70, 3, 9, 4, 242],
#  [156],
#  [26,
#   79,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [76, 65],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   243,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [143, 30],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [64, 4, 135, 124],
#  [49, 43],
#  [10, 5, 7, 4, 170],
#  [125, 65],
#  [136, 8, 59, 49, 171],
#  [141,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [73, 59, 172],
#  [64, 4, 110, 137],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [76],
#  [17, 7, 4, 173],
#  [10, 15, 4, 160, 126],
#  [1, 109, 115, 124],
#  [45, 30],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 35, 1, 33, 3, 5, 7, 11],
#  [10, 15, 4, 135, 124],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [128,
#   146,
#   1,
#   147,
#   148,
#   149,
#   27,
#   1,
#   31,
#   8,
#   33,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 158, 2, 11, 102, 3, 5, 7],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 244],
#  [120, 30],
#  [43, 10, 7, 4, 174],
#  [43, 10, 7, 4, 175],
#  [3, 7, 4, 176],
#  [25, 4, 115, 124],
#  [141,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [96,
#   6,
#   17,
#   48,
#   1,
#   18,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [136, 8, 59, 49, 177],
#  [73, 81, 11, 59, 178],
#  [45, 65],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   245,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [41, 2, 28, 81, 3, 7, 179],
#  [73, 81, 11, 59, 180],
#  [125, 65],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 246],
#  [129, 150, 124],
#  [30, 6, 70, 3, 9, 4, 247],
#  [84, 41, 2],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [84, 41, 2],
#  [76],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 35, 1, 116, 3, 5, 7],
#  [64, 4, 10, 5, 7, 180],
#  [73, 81, 11, 59, 169],
#  [76, 65],
#  [43],
#  [120, 30],
#  [73, 59, 17, 5, 7, 181],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 248],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 35, 1, 33, 3, 5, 7, 11],
#  [45, 65],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   249,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [30, 6, 70, 9, 13, 3, 5, 4, 250],
#  [141,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 251],
#  [163],
#  [117, 25],
#  [120, 30],
#  [26,
#   79,
#   146,
#   1,
#   147,
#   148,
#   149,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [41, 2, 28, 81, 3, 7, 182],
#  [64, 4, 10, 5, 7, 183],
#  [45, 65],
#  [49, 110, 137],
#  [143, 30],
#  [128,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [26,
#   79,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [30, 6, 70, 3, 9, 4, 252],
#  [26,
#   138,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [30, 133, 3, 15, 2, 29, 253, 13, 3, 5],
#  [25, 4, 254],
#  [112, 74],
#  [125, 65],
#  [45, 30],
#  [163],
#  [112, 74],
#  [1, 109, 110, 126],
#  [96,
#   6,
#   17,
#   48,
#   1,
#   18,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [49, 115, 124],
#  [151],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [30, 133, 3, 15, 2, 29, 255, 13, 3, 5],
#  [113,
#   146,
#   1,
#   147,
#   148,
#   149,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 158, 2, 11, 102, 3, 5, 7],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 256],
#  [49, 43],
#  [3, 7, 4, 184],
#  [84, 41, 2],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [45, 30],
#  [43, 10, 7, 4, 185],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   257,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [41, 2, 28, 81, 3, 7, 186],
#  [30, 6, 70, 9, 13, 3, 5, 4, 258],
#  [117, 25],
#  [41, 2, 28, 81, 3, 7, 187],
#  [76, 65],
#  [45, 65],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [45, 30],
#  [49, 110, 164],
#  [26,
#   138,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [30, 133, 3, 15, 2, 29, 259, 13, 3, 5],
#  [1, 109, 135, 137],
#  [129, 115, 126],
#  [25, 4, 188],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 158, 2, 11, 102, 3, 5, 7],
#  [151],
#  [76],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 260],
#  [1, 109, 110, 130],
#  [49, 160, 130],
#  [49, 43],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [73, 59, 17, 5, 7, 189],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 261],
#  [112, 74],
#  [17, 7, 4, 190],
#  [156],
#  [49, 134],
#  [30, 133, 3, 15, 2, 29, 262, 13, 3, 5],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [49, 134],
#  [151],
#  [25, 4, 178],
#  [30, 133, 3, 15, 2, 29, 263, 13, 3, 5],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   264,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [26],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 22, 2, 11, 21, 20, 3, 5, 7],
#  [26],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 3, 5, 7, 11, 40],
#  [26,
#   138,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [43, 10, 7, 4, 191],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   265,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   266,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [151],
#  [120, 30],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   267,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [25, 4, 110, 124],
#  [141,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [117, 25],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [64, 4, 110, 130],
#  [84, 41, 2],
#  [43],
#  [43],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   35,
#   1,
#   116,
#   3,
#   5,
#   7],
#  [73, 59, 192],
#  [26,
#   79,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [45, 65],
#  [49, 43],
#  [117, 25],
#  [84, 41, 2],
#  [73, 59, 17, 5, 7, 193],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   268,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [26,
#   138,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [45, 30],
#  [43],
#  [45, 30],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [73, 59, 17, 5, 7, 194],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 269],
#  [49, 150, 130],
#  [143, 30],
#  [64, 4, 150, 137],
#  [64, 4, 115, 124],
#  [30, 6, 70, 3, 9, 4, 270],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [84, 41, 2],
#  [43],
#  [43, 10, 7, 4, 195],
#  [25, 4, 115, 132],
#  [49, 43],
#  [30, 6, 70, 9, 13, 3, 5, 4, 271],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   22,
#   2,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 272],
#  [128,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [26],
#  [41, 2, 28, 81, 3, 7, 190],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   273,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   274,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [84, 41, 2],
#  [17, 7, 4, 171],
#  [129, 159, 126],
#  [125, 65],
#  [141,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [120, 30],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [26],
#  [156],
#  [1, 109, 110, 137],
#  [112, 74],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   275,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [64, 4, 10, 5, 7, 196],
#  [76],
#  [26,
#   138,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [64, 4, 10, 5, 7, 184],
#  [25, 4, 197],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [1, 109, 150, 130],
#  [113,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   27,
#   1,
#   31,
#   8,
#   33,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [26,
#   79,
#   146,
#   1,
#   147,
#   148,
#   149,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [151],
#  [1, 109, 150, 126],
#  [143, 30],
#  [143, 30],
#  [156],
#  [125, 65],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [120, 30],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 35, 1, 33, 3, 5, 7, 11],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   276,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [25, 4, 110, 126],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 277],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [64, 4, 10, 5, 7, 198],
#  [113,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [30, 6, 70, 3, 9, 4, 278],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [49, 110, 164],
#  [76],
#  [41, 2, 28, 81, 3, 7, 170],
#  [117, 25],
#  [49, 134],
#  [17, 7, 4, 186],
#  [43],
#  [26,
#   138,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [96,
#   6,
#   17,
#   48,
#   1,
#   18,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [10, 5, 7, 4, 199],
#  [163],
#  [1, 109, 110, 124],
#  [129, 110, 137],
#  [30, 133, 3, 15, 2, 29, 279, 13, 3, 5],
#  [120, 30],
#  [17, 7, 4, 200],
#  [73, 81, 11, 59, 197],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [128,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [3, 7, 4, 201],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 35, 1, 116, 3, 5, 7],
#  [113,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [73, 81, 11, 59, 202],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [1, 109, 115, 126],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 35, 1, 116, 3, 5, 7],
#  [84, 41, 2],
#  [125, 65],
#  [43],
#  [30, 6, 70, 3, 9, 4, 280],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   281,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [73, 59, 183],
#  [76],
#  [113,
#   146,
#   1,
#   147,
#   148,
#   149,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [49, 43],
#  [25, 4, 135, 132],
#  [30, 6, 70, 3, 9, 4, 282],
#  [10, 5, 7, 4, 203],
#  [73, 59, 283],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   284,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [45, 65],
#  [84, 41, 2],
#  [17, 7, 4, 202],
#  [26],
#  [143, 30],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   285,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   286,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [76, 65],
#  [49, 115, 137],
#  [66,
#   17,
#   48,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   111,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [129, 160, 126],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 35, 1, 33, 3, 5, 7, 11],
#  [64, 4, 115, 132],
#  [17, 7, 4, 179],
#  [76],
#  [17, 7, 4, 204],
#  [30, 6, 70, 9, 13, 3, 5, 4, 287],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 35, 1, 116, 3, 5, 7],
#  [3, 7, 4, 195],
#  [97,
#   8,
#   33,
#   12,
#   161,
#   162,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   288,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 289],
#  [43],
#  [120, 30],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   290,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   35,
#   1,
#   33,
#   3,
#   5,
#   7,
#   11],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 35, 1, 116, 3, 5, 7],
#  [96, 8, 33, 155, 3, 46, 34, 18, 103, 16, 2, 14, 12, 35, 1, 116, 3, 5, 7],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   291,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   158,
#   2,
#   11,
#   102,
#   3,
#   5,
#   7],
#  [45, 30],
#  [113,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [113,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [97,
#   8,
#   33,
#   12,
#   161,
#   162,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   292,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [41, 2, 28, 81, 3, 7, 205],
#  [45, 65],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [117, 25],
#  [96,
#   6,
#   17,
#   48,
#   1,
#   18,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [112, 74],
#  [49, 134],
#  [113,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [120, 30],
#  [141,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   293,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [112, 74],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   294,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [17, 7, 4, 295],
#  [143, 30],
#  [129, 110, 164],
#  [128,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 35, 1, 33, 3, 5, 7, 11],
#  [120, 30],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [30, 133, 3, 15, 2, 29, 296, 13, 3, 5],
#  [151],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 35, 1, 116, 3, 5, 7],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [73, 81, 11, 59, 196],
#  [25, 4, 206],
#  [45, 65],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   297,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [64, 4, 10, 5, 7, 207],
#  [25, 4, 159, 164],
#  [73, 59, 208],
#  [45, 65],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   298,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [26],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [30, 6, 70, 3, 9, 4, 299],
#  [64, 4, 10, 5, 7, 209],
#  [49, 134],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   300,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   301,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [76],
#  [30, 133, 3, 15, 2, 29, 302, 13, 3, 5],
#  [26,
#   79,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [49, 43],
#  [1, 109, 160, 126],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 303],
#  [141,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [97,
#   8,
#   33,
#   12,
#   161,
#   162,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   304,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [128,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [3, 7, 4, 185],
#  [49, 110, 137],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [151],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [41, 2, 28, 81, 3, 7, 175],
#  [64, 4, 10, 5, 7, 210],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   305,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [49, 134],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   306,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [41, 2, 28, 81, 3, 7, 210],
#  [129, 115, 132],
#  [49, 211],
#  [76],
#  [17, 7, 4, 307],
#  [10, 15, 4, 135, 132],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 308],
#  [30, 6, 70, 9, 13, 3, 5, 4, 309],
#  [117, 25],
#  [25, 4, 212],
#  [30, 6, 70, 9, 13, 3, 5, 4, 310],
#  [73, 59, 17, 5, 7, 311],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 22, 2, 11, 21, 20, 3, 5, 7],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 22, 2, 11, 21, 20, 3, 5, 7],
#  [26,
#   145,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [112, 74],
#  [117, 25],
#  [117, 25],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   312,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [129, 110, 132],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   313,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [30, 6, 70, 3, 9, 4, 314],
#  [117, 25],
#  [45, 65],
#  [141,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [117, 25],
#  [3, 7, 4, 203],
#  [26],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   315,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [64, 4, 135, 137],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 3, 5, 7, 11, 40],
#  [26],
#  [49, 115, 130],
#  [120, 30],
#  [128,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [84, 41, 2],
#  [129, 159, 132],
#  [45, 30],
#  [113,
#   146,
#   1,
#   147,
#   148,
#   149,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [143, 30],
#  [125, 65],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   316,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [10, 15, 4, 159, 126],
#  [112, 74],
#  [117, 25],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [17, 7, 4, 192],
#  [49, 159, 130],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [26,
#   138,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [113,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [143, 30],
#  [3, 7, 4, 204],
#  [64, 4, 10, 5, 7, 213],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [84, 41, 2],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 22, 2, 11, 21, 20, 3, 5, 7],
#  [128,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [143, 30],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 317],
#  [49, 134],
#  [49, 134],
#  [1, 109, 135, 124],
#  [76],
#  [64, 4, 10, 5, 7, 318],
#  [73, 59, 17, 5, 7, 319],
#  [26,
#   138,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [43],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   35,
#   1,
#   116,
#   3,
#   5,
#   7],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 320],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   321,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [112, 74],
#  [129, 135, 164],
#  [1, 109, 160, 130],
#  [113,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [76, 65],
#  [10, 15, 4, 150, 126],
#  [26,
#   138,
#   146,
#   1,
#   147,
#   148,
#   149,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [43, 10, 7, 4, 177],
#  [125, 65],
#  [125, 65],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [10, 15, 4, 115, 130],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   22,
#   2,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7],
#  [45, 30],
#  [125, 65],
#  [3, 7, 4, 214],
#  [76],
#  [113,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   27,
#   1,
#   31,
#   8,
#   33,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [30, 133, 3, 15, 2, 29, 322, 13, 3, 5],
#  [76, 65],
#  [10, 5, 7, 4, 215],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [45, 65],
#  [30, 6, 70, 3, 9, 4, 323],
#  [73, 59, 216],
#  [128,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   27,
#   1,
#   31,
#   8,
#   33,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [64, 4, 10, 5, 7, 217],
#  [26,
#   79,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [163],
#  [45, 65],
#  [30, 133, 3, 15, 2, 29, 324, 13, 3, 5],
#  [41, 2, 28, 81, 3, 7, 325],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 22, 2, 11, 21, 20, 3, 5, 7],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 326],
#  [25, 4, 110, 132],
#  [129, 150, 124],
#  [96, 8, 33, 155, 3, 46, 34, 18, 103, 16, 2, 14, 12, 158, 2, 11, 102, 3, 5, 7],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 22, 2, 11, 21, 20, 3, 5, 7],
#  [73, 81, 11, 59, 327],
#  [30, 133, 3, 15, 2, 29, 328, 13, 3, 5],
#  [17, 7, 4, 182],
#  [97,
#   8,
#   33,
#   12,
#   161,
#   162,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   329,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [30, 6, 70, 9, 13, 3, 5, 4, 330],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [45, 65],
#  [45, 30],
#  [49, 134],
#  [113,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 331],
#  [136, 8, 59, 49, 218],
#  [163],
#  [1, 109, 150, 124],
#  [76, 65],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [156],
#  [26],
#  [17, 7, 4, 219],
#  [41, 2, 28, 81, 3, 7, 213],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   332,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [73, 59, 17, 5, 7, 215],
#  [141,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [84, 41, 2],
#  [163],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 35, 1, 33, 3, 5, 7, 11],
#  [120, 30],
#  [1, 109, 160, 132],
#  [17, 7, 4, 220],
#  [43, 10, 7, 4, 214],
#  [10, 15, 4, 159, 126],
#  [49, 134],
#  [10, 5, 7, 4, 189],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   333,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   334,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [1, 109, 135, 137],
#  [45, 30],
#  [41, 2, 28, 81, 3, 7, 200],
#  [17, 7, 4, 221],
#  [49, 193],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   3,
#   5,
#   7,
#   11,
#   40],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [151],
#  [66,
#   17,
#   48,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   111,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [64, 4, 115, 137],
#  [156],
#  [30, 6, 70, 3, 9, 4, 335],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [30, 133, 3, 15, 2, 29, 336, 13, 3, 5],
#  [129, 150, 137],
#  [1, 109, 160, 132],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [97,
#   8,
#   16,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   337,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [156],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 35, 1, 116, 3, 5, 7],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [49, 134],
#  [10, 15, 4, 115, 126],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [156],
#  [117, 25],
#  [1, 109, 135, 137],
#  [84, 41, 2],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 35, 1, 116, 3, 5, 7],
#  [26,
#   79,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [26],
#  [3, 7, 4, 222],
#  [125, 65],
#  [113,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [49, 134],
#  [136, 8, 59, 49, 223],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   338,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [45, 65],
#  [26,
#   79,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [3, 7, 4, 224],
#  [26],
#  [10, 5, 7, 4, 225],
#  [41, 2, 28, 81, 3, 7, 226],
#  [25, 4, 110, 130],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   339,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [3, 7, 4, 211],
#  [129, 135, 132],
#  [3, 7, 4, 165],
#  [112, 74],
#  [113,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   27,
#   1,
#   31,
#   8,
#   33,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [73, 81, 11, 59, 173],
#  [113,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   27,
#   1,
#   31,
#   8,
#   33,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   340,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [45, 30],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 341],
#  [43, 10, 7, 4, 172],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [41, 2, 28, 81, 3, 7, 206],
#  [112, 74],
#  [129, 135, 130],
#  [25, 4, 110, 130],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   342,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [1, 109, 115, 124],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [117, 25],
#  [136, 8, 59, 49, 207],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   343,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [97,
#   8,
#   16,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   344,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [43],
#  [112, 74],
#  [113,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   27,
#   1,
#   31,
#   8,
#   33,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [136, 8, 59, 49, 212],
#  [43, 10, 7, 4, 216],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 3, 5, 7, 11, 40],
#  [73, 59, 199],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [76, 65],
#  [76, 65],
#  [112, 74],
#  [120, 30],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [76],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   345,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [43, 10, 7, 4, 346],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 35, 1, 116, 3, 5, 7],
#  [26,
#   145,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [156],
#  [30, 6, 70, 3, 9, 4, 347],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [30, 6, 70, 3, 9, 4, 348],
#  [43],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   349,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [73, 59, 17, 5, 7, 227],
#  [73, 59, 17, 5, 7, 228],
#  [73, 59, 17, 5, 7, 229],
#  [64, 4, 150, 124],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   350,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [129, 115, 137],
#  [26,
#   138,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [125, 65],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 351],
#  [128,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [73, 59, 217],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   352,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 3, 5, 7, 11, 40],
#  [96,
#   6,
#   17,
#   48,
#   1,
#   18,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [76, 65],
#  [112, 74],
#  [120, 30],
#  [49, 43],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   353,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 158, 2, 11, 102, 3, 5, 7],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [73, 59, 230],
#  [141,
#   146,
#   1,
#   147,
#   148,
#   149,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [30, 133, 3, 15, 2, 29, 354, 13, 3, 5],
#  [136, 8, 59, 49, 231],
#  [17, 7, 4, 176],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [73, 81, 11, 59, 232],
#  [26],
#  [49, 43],
#  [26,
#   138,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [73, 59, 233],
#  [26,
#   79,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [41, 2, 28, 81, 3, 7, 355],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 356],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 357],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [1,
#   66,
#   17,
#   48,
#   92,
#   28,
#   127,
#   68,
#   25,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [112, 74],
#  [49, 43],
#  [136, 8, 59, 49, 174],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   358,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [49, 160, 130],
#  [45, 30],
#  [73, 59, 17, 5, 7, 221],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   359,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [97,
#   8,
#   33,
#   12,
#   161,
#   162,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   360,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [97,
#   8,
#   16,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   361,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [30, 6, 70, 9, 13, 3, 5, 4, 362],
#  [43],
#  [26],
#  [117, 25],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 363],
#  [45, 65],
#  [97,
#   8,
#   16,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   364,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [74, 11, 21, 20, 3, 15, 6, 32, 42],
#  [128,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   22,
#   2,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 365],
#  [45, 65],
#  [43],
#  [25, 4, 201],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 366],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 3, 5, 7, 11, 40],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 367],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [97,
#   8,
#   16,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   368,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [30, 6, 70, 9, 13, 3, 5, 4, 369],
#  [43, 10, 7, 4, 370],
#  [26,
#   79,
#   146,
#   1,
#   147,
#   148,
#   149,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 371],
#  [49, 234],
#  [125, 65],
#  [43],
#  [49, 235],
#  [117, 25],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [76],
#  [97,
#   8,
#   33,
#   12,
#   161,
#   162,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   372,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [49, 135, 132],
#  [10, 5, 7, 4, 222],
#  [76, 65],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 35, 1, 116, 3, 5, 7],
#  [125, 65],
#  [64, 4, 10, 5, 7, 205],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 3, 5, 7, 11, 40],
#  [41, 2, 28, 81, 3, 7, 168],
#  [26,
#   138,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [30, 6, 70, 3, 9, 4, 373],
#  [1, 109, 150, 132],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [97,
#   8,
#   16,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   374,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 158, 2, 11, 102, 3, 5, 7],
#  [113,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [113,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 375],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 376],
#  [76],
#  [1, 109, 115, 130],
#  [30, 6, 70, 3, 9, 4, 377],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [25, 4, 226],
#  [45, 30],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [128,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   22,
#   2,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 378],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [26,
#   79,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [43, 10, 7, 4, 194],
#  [136, 8, 59, 49, 379],
#  [136, 8, 59, 49, 188],
#  [117, 25],
#  [25, 4, 150, 132],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   22,
#   2,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7],
#  [97,
#   8,
#   16,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   380,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [49, 236],
#  [1, 109, 135, 132],
#  [3, 7, 4, 236],
#  [97,
#   8,
#   33,
#   12,
#   161,
#   162,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   381,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   382,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [64, 4, 10, 5, 7, 232],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 35, 1, 116, 3, 5, 7],
#  [76],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   383,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [49, 160, 124],
#  [43],
#  [3, 7, 4, 191],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 384],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   385,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [112, 74],
#  [73, 59, 17, 5, 7, 225],
#  [49, 134],
#  [45, 30],
#  [26],
#  [136, 8, 59, 49, 386],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 35, 1, 116, 3, 5, 7],
#  [45, 30],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 35, 1, 116, 3, 5, 7],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   387,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [151],
#  [76],
#  [76],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 388],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   389,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [64, 4, 110, 130],
#  [113,
#   146,
#   1,
#   147,
#   148,
#   149,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   35,
#   1,
#   116,
#   3,
#   5,
#   7],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   22,
#   2,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7],
#  [76],
#  [128,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [49, 159, 132],
#  [84, 41, 2],
#  [26, 6, 32, 42, 22, 2, 11, 102, 3, 15, 54, 13, 17, 55],
#  [43, 10, 7, 4, 233],
#  [30, 6, 70, 9, 13, 3, 5, 4, 390],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   391,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [41, 2, 28, 81, 3, 7, 392],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 158, 2, 11, 102, 3, 5, 7],
#  [112, 74],
#  [76],
#  [45, 65],
#  [76, 65],
#  [96, 6, 17, 48, 1, 18, 16, 2, 14, 12, 158, 2, 11, 102, 3, 5, 7],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 393],
#  [151],
#  [45, 30],
#  [25, 4, 110, 130],
#  [25, 4, 218],
#  [45, 30],
#  [64, 4, 10, 5, 7, 394],
#  [41, 2, 28, 81, 3, 7, 198],
#  [17, 7, 4, 181],
#  [49, 395],
#  [112, 74],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [76],
#  [41, 2, 6, 70, 3, 15, 3, 9, 4, 396],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 3, 5, 7, 11, 40],
#  [30, 133, 3, 15, 2, 29, 397, 13, 3, 5],
#  [96,
#   6,
#   17,
#   48,
#   1,
#   18,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [25, 4, 228],
#  [73, 81, 11, 59, 398],
#  [26,
#   79,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [49, 134],
#  [156],
#  [17, 7, 4, 167],
#  [1,
#   18,
#   154,
#   40,
#   34,
#   18,
#   103,
#   68,
#   25,
#   1,
#   66,
#   17,
#   48,
#   92,
#   40,
#   1,
#   28,
#   16,
#   2,
#   14,
#   12,
#   35,
#   1,
#   33,
#   3,
#   5,
#   7,
#   11],
#  [26,
#   138,
#   146,
#   1,
#   147,
#   148,
#   149,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   18,
#   2,
#   21,
#   10,
#   9],
#  [120, 30],
#  [97,
#   8,
#   33,
#   12,
#   161,
#   162,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   399,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [141,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [66, 17, 48, 1, 28, 16, 2, 14, 12, 111, 35, 1, 116, 3, 5, 7],
#  [26],
#  [30, 6, 70, 9, 13, 3, 5, 4, 400],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [26,
#   79,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [120, 30],
#  [49, 159, 164],
#  [49, 134],
#  [156],
#  [136, 8, 59, 49, 234],
#  [30, 6, 70, 9, 13, 3, 5, 4, 401],
#  [136, 8, 59, 49, 402],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 35, 1, 33, 3, 5, 7, 11],
#  [73, 59, 237],
#  [64, 4, 10, 5, 7, 229],
#  [41, 2, 28, 81, 3, 7, 403],
#  [120, 30],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   404,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [30, 6, 70, 3, 9, 4, 405],
#  [17, 7, 4, 227],
#  [84, 41, 2],
#  [64, 4, 10, 5, 7, 187],
#  [25, 4, 110, 126],
#  [96, 8, 33, 155, 3, 46, 34, 18, 103, 16, 2, 14, 12, 35, 1, 33, 3, 5, 7, 11],
#  [97,
#   8,
#   16,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   406,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [43, 10, 7, 4, 230],
#  [43, 10, 7, 4, 224],
#  [80,
#   34,
#   108,
#   75,
#   16,
#   8,
#   2,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   407,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   18,
#   53,
#   2,
#   14],
#  [128,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   1,
#   44,
#   139,
#   6,
#   5,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [76, 65],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 158, 2, 11, 102, 3, 5, 7],
#  [49, 223],
#  [128,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 22, 2, 11, 21, 20, 3, 5, 7],
#  [84, 41, 2],
#  [141,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   27,
#   1,
#   31,
#   8,
#   33,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [76, 65],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [25, 4, 408],
#  [30, 6, 70, 3, 9, 4, 409],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [112, 74],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 410],
#  [41, 2, 40, 50, 8, 142, 3, 15, 22, 2, 11, 21, 20, 3, 15, 40],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   18,
#   2,
#   16,
#   20,
#   14,
#   64],
#  [125, 65],
#  [30, 133, 3, 15, 2, 29, 411, 13, 3, 5],
#  [73, 59, 17, 5, 7, 219],
#  [26,
#   138,
#   10,
#   91,
#   118,
#   119,
#   47,
#   62,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [49, 43],
#  [43],
#  [151],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 412],
#  [3, 7, 4, 220],
#  [64, 4, 10, 5, 7, 237],
#  [84, 41, 2],
#  [43, 3, 15, 144, 14, 55, 13, 3, 5, 2, 29, 413],
#  [41, 2, 28, 81, 3, 7, 235],
#  [30, 6, 70, 3, 9, 4, 414],
#  [41, 2, 6, 15, 32, 3, 9, 54, 75, 62, 4, 415],
#  [45, 65],
#  [76],
#  [117, 25],
#  [17, 7, 4, 231],
#  [1, 109, 159, 124],
#  [84, 22, 2, 11, 140, 20, 33, 3, 15, 6, 32, 42],
#  [26],
#  [73, 81, 11, 59, 209],
#  [152, 26, 11, 153, 3, 15, 54, 13, 17, 55, 6, 32, 42],
#  [76],
#  [25, 4, 115, 126],
#  [97,
#   12,
#   34,
#   22,
#   16,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   416,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [26,
#   145,
#   1,
#   31,
#   8,
#   157,
#   47,
#   8,
#   10,
#   91,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [1, 66, 17, 48, 92, 28, 127, 68, 25, 35, 1, 33, 3, 5, 7, 11],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   417,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   418,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [143, 30],
#  [128,
#   1,
#   31,
#   8,
#   131,
#   47,
#   69,
#   10,
#   5,
#   27,
#   1,
#   44,
#   8,
#   63,
#   9,
#   1,
#   44,
#   13,
#   93,
#   94,
#   95,
#   52,
#   19,
#   10,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   50,
#   56,
#   98,
#   99,
#   6,
#   23,
#   27,
#   24,
#   46,
#   11,
#   100,
#   36,
#   7,
#   6,
#   12,
#   419,
#   101,
#   57,
#   28,
#   19,
#   60,
#   8,
#   2,
#   61,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [26,
#   79,
#   1,
#   114,
#   51,
#   77,
#   78,
#   62,
#   79,
#   58,
#   1,
#   31,
#   8,
#   63,
#   10,
#   9,
#   82,
#   1,
#   52,
#   19,
#   25,
#   13,
#   23,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [45, 65],
#  [26,
#   79,
#   1,
#   31,
#   8,
#   68,
#   51,
#   77,
#   78,
#   1,
#   44,
#   8,
#   63,
#   71,
#   72,
#   47,
#   1,
#   29,
#   13,
#   10,
#   5,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   71,
#   72,
#   1,
#   29,
#   13,
#   10,
#   5],
#  [43],
#  [151],
#  [136, 8, 59, 49, 420],
#  [125, 65],
#  [129, 159, 126],
#  [26,
#   12,
#   34,
#   121,
#   3,
#   122,
#   1,
#   29,
#   56,
#   85,
#   86,
#   6,
#   23,
#   27,
#   24,
#   46,
#   3,
#   36,
#   7,
#   4,
#   421,
#   87,
#   19,
#   51,
#   88,
#   69,
#   89,
#   57,
#   90,
#   4,
#   37,
#   38,
#   39,
#   1,
#   35,
#   53,
#   2,
#   14],
#  [3, 7, 4, 422],
#  [80,
#   34,
#   22,
#   16,
#   2,
#   50,
#   104,
#   105,
#   67,
#   23,
#   27,
#   24,
#   106,
#   36,
#   7,
#   6,
#   12,
#   4,
#   423,
#   107,
#   19,
#   60,
#   8,
#   2,
#   61,
#   67,
#   12,
#   4,
#   37,
#   38,
#   39,
#   40],
#  [96,
#   8,
#   33,
#   155,
#   3,
#   46,
#   34,
#   18,
#   103,
#   16,
#   2,
#   14,
#   12,
#   11,
#   21,
#   20,
#   3,
#   5,
#   7,
#   58,
#   12,
#   1,
#   18,
#   16,
#   2,
#   14,
#   3,
#   5,
#   9],
#  [43, 6, 123, 32, 42, 35, 1, 33, 3, 15, 54, 13, 17, 55],
#  [49, 43],
#  [141,
#   146,
#   1,
#   147,
#   148,
#   149,
#   58,
#   1,
#   31,
#   8,
#   33,
#   10,
#   5,
#   9,
#   45,
#   24,
#   4,
#   83,
#   5,
#   9,
#   22,
#   2,
#   11,
#   21,
#   20,
#   10,
#   5,
#   9],
#  [64, 4, 10, 5, 7, 208]]

# %%
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  53,   2,  14],
#        [  0,   0,   0, ...,   0,  49, 165],
#        [  0,   0,   0, ...,   7,   4, 166],
#        ...,
#        [  0,   0,   0, ...,   0,  49,  43],
#        [  0,   0,   0, ...,  10,   5,   9],
#        [  0,   0,   0, ...,   5,   7, 208]])

# %%
def RNN():
    inputs = Input(name='inputs',shape=[max_len])
    layer = Embedding(max_words,50,input_length=max_len)(inputs)
    layer = LSTM(64)(layer)
    layer = Dense(256,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.5)(layer)
    layer = Dense(1,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

# %%
model = RNN()
model.summary()
model.compile(loss='sparse_categorical_crossentropy',optimizer=SGD,metrics=['accuracy'])
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 150)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 150, 50)           50000
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# FC1 (Dense)                  (None, 256)               16640
# _________________________________________________________________
# activation_9 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 1)                 257
# _________________________________________________________________
# activation_10 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 96,337
# Trainable params: 96,337
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-809e22cd2c30> in <module>
#       1 model = RNN()
#       2 model.summary()
# ----> 3 model.compile(loss='sparse_categorical_crossentropy',optimizer=SGD,metrics=['accuracy'])
#
# NameError: name 'SGD' is not defined

# %%
model.fit(sequences_matrix,Y_train,batch_size=128,epochs=100,
          validation_split=0.2)
# Out:
# Train on 748 samples, validate on 187 samples
# Epoch 1/100
# 748/748 [==============================] - 1s 991us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 2/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 3/100
# 748/748 [==============================] - 1s 976us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 4/100
# 748/748 [==============================] - 1s 988us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 5/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 6/100
# 748/748 [==============================] - 1s 956us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 7/100
# 748/748 [==============================] - 1s 971us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 8/100
# 748/748 [==============================] - 1s 977us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 9/100
# 748/748 [==============================] - 1s 979us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 10/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 11/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 12/100
# 748/748 [==============================] - 1s 975us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 13/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 14/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 15/100
# 748/748 [==============================] - 1s 974us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 16/100
# 748/748 [==============================] - 1s 969us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 17/100
# 748/748 [==============================] - 1s 970us/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 18/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 19/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 20/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 21/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 22/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 23/100
# 748/748 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.2714 - val_loss: nan - val_accuracy: 0.2620
# Epoch 24/100
# 256/748 [=========>....................] - ETA: 0s - loss: nan - accuracy: 0.2617
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-76cbf9ae4353> in <module>
#       1 model.fit(sequences_matrix,Y_train,batch_size=128,epochs=100,
# ----> 2           validation_split=0.2)
#
# ~\Anaconda3\envs\workgpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\envs\workgpu\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\envs\workgpu\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~\Anaconda3\envs\workgpu\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
import tensorflow as tf

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = sequence.pad_sequences(test_sequences,maxlen=max_len)

# %%
accr = model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 165/165 [==============================] - 0s 2ms/step

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# Test set
#   Loss: nan
#   Accuracy: 0.285
